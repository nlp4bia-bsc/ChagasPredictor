# %%
import logging
import torch
import numpy as np
from typing import Dict
from accelerate import Accelerator
from torch.utils.data import DataLoader
from torch.optim import AdamW
from transformers import AutoTokenizer, RobertaConfig, get_scheduler
import operator
import os

from models.overlap_bert import MeanBERT, LSTMBERT
from data.dataset import OverlapDataset, collate_cases, collate_cases_time, DateVisitsDataset
from data.load_data import load_real_data
from pipeline.multi_bert import train_epoch, evaluate_model
from utils.evaluation import singlelabel_eval

from utils.import_config import import_config
from utils.logger import setup_logger

# %%
comparison_ops = {
    'val_loss': operator.lt,
    'ham_loss': operator.lt,
    'val_accuracy': operator.gt,
    'val_macro_f1': operator.gt,
    'val_weighted_f1': operator.gt,
}

# %%
class temp_args:
    def __init__(self):
        self.action = 'train'
        self.log = 'info'

args = temp_args()
config = import_config("config.yaml")

logger = setup_logger(config['general']['log_dir'], args)
# Out:
# Loading configuration from config/config.yaml

# %% [markdown]
# # Data

# %%
train_df, test_df, val_df = load_real_data(config['general']['dataset'], stratify_col='label', test_size=0.2, dev_size=0.1)

tokenizer = AutoTokenizer.from_pretrained(config['model']['tokenizer_path'])
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

method = 'lstm-attn'

output_dir = os.path.join(config['training']['output_dir'], method)

# Create datasets and dataloaders
train_dataset = OverlapDataset(train_df['visits'].to_list(), train_df['label'].to_list())
val_dataset = OverlapDataset(val_df['visits'].to_list(), val_df['label'].to_list())
test_dataset = OverlapDataset(test_df['visits'].to_list(), test_df['label'].to_list())

train_loader = DataLoader(
    train_dataset, 
    batch_size=config['training']['batch_size'], 
    shuffle=True, 
    collate_fn=lambda b: collate_cases(b, tokenizer, max_length=512)
    )
val_loader = DataLoader(
    val_dataset, 
    batch_size=config['training']['batch_size'], 
    collate_fn=lambda b: collate_cases(b, tokenizer, max_length=512)
    )
test_loader = DataLoader(
    test_dataset, 
    batch_size=config['training']['batch_size'], 
    collate_fn=lambda b: collate_cases(b, tokenizer, max_length=512)
    )

# %% [markdown]
# # Model

# %%
hf_config = RobertaConfig.from_pretrained(config['model']['tokenizer_path'])
hf_config.loss_fct = config['training']['loss']
hf_config.output_dim = config['model']['output_dim']
hf_config.num_tasks = config['model']['num_tasks']
hf_config.freeze_bert = config['model']['freeze_bert']
hf_config.classifier_dropout = config['model']['dropout']
if method == 'mean':
    model = MeanBERT(hf_config, pretrained_model=config['model']['pretrained_model'])
elif method == 'lstm':
    hf_config.lstm_hidden = 256
    model = LSTMBERT(hf_config, pretrained_model=config['model']['pretrained_model'])
elif method == 'lstm-attn':
    hf_config.lstm_hidden = 256
    hf_config.attn_dim = 128
    model = LSTMBERT(hf_config, pretrained_model=config['model']['pretrained_model'])
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# Initialize training methods
accelerator = Accelerator()
optimizer = AdamW(model.parameters(), lr=config['training']['learning_rate'])

num_epochs = config['training']['num_epochs']
num_training_steps = num_epochs * len(train_loader)
scheduler = get_scheduler(
    "linear", optimizer=optimizer, num_warmup_steps=0, num_training_steps=num_training_steps
)

model, optimizer, train_loader, val_loader, test_loader, scheduler = accelerator.prepare(
    model, optimizer, train_loader, val_loader, test_loader, scheduler
)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at /home/isglobal.lan/erodriguez1/.cache/huggingface/hub/models--PlanTL-GOB-ES--bsc-bio-ehr-es/snapshots/cb0a3d3d85692d19e7cbd8b3f02f9263fa343837 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # Train

# %%
# Training loop
best_es_metric_val = 0
es_drag = 0
es_metric = config['training']['early_stopping_metric']
es_patience = config['training']['early_stopping_patience']
es_compare = comparison_ops[es_metric]
for epoch in range(num_epochs):
    logger.info(f"\nEpoch {epoch + 1}/{num_epochs}")
    logger.info("-" * 50)
    
    # Train
    train_loss = train_epoch(
        model, train_loader, optimizer, scheduler, device
    )
    logger.info(f"Train Loss: {train_loss:.4f}")
    
    # Evaluate
    val_loss, preds, actual = evaluate_model(
        model, val_loader, device
    )
    logger.info(f"Val Loss: {val_loss:.4f}")

    val_metrics = singlelabel_eval(
        np.array(actual),
        np.array(preds),
        logging.getLogger(),
        target_names=['Neither', 'Cardiological Only', 'Digestive Only',]
    )
    val_metrics['es']['val_loss'] = val_loss  
    logger.info(f"Val {es_metric}: {val_metrics['es'][es_metric]:.4f}")

    # Save best model based on average F1 score
    if es_compare(val_metrics['es'][es_metric], best_es_metric_val) or epoch == 0:
        best_es_metric_val = val_metrics['es'][es_metric]
        accelerator.wait_for_everyone()
        unwrapped_model = accelerator.unwrap_model(model)
        unwrapped_model.save_pretrained(output_dir, save_function=accelerator.save)
        tokenizer.save_pretrained(output_dir)
        logger.info(f"New best model saved in {output_dir}!")
        es_drag = 0
    else:
        es_drag += 1
        if es_drag >= es_patience:
            logger.info(f"Early stopping triggered after {epoch+1} epochs.")
            break

# %% [markdown]
# # Miscellaneous

# %%
visits_df = train_df['visits'].explode()

# %%
len("16oct2009 ")
# Out:
# 10

# %%
"22jan2010ñlkjj"[9:]
# Out:
# 'ñlkjj'

# %%
from typing import List, Union
from datetime import timedelta, date

def impute_missing_dates(dates: List[Union[date,None]]) -> List[date]:
    if all(d is None for d in dates):
        return [date(2024, 1, 1) for _ in dates]
    elif all(d is not None for d in dates):
        return dates

    n = len(dates)
    result = dates.copy()

    # Fill missing in middle using avg of left and right
    for i in range(n):
        if result[i] is None:
            # find left
            left = next((result[j] for j in range(i - 1, -1, -1) if result[j] is not None), None)
            # find right
            right = next((result[j] for j in range(i + 1, n) if result[j] is not None), None)

            if left and right:
                avg_seconds = (left.timestamp() + right.timestamp()) / 2
                result[i] = date.fromtimestamp(avg_seconds)
            elif left and not right:
                result[i] = left + timedelta(days=1)
            elif right and not left:
                result[i] = right - timedelta(days=1)
            else:
                result[i] = date(2024, 1, 1)

    return result
def pop_dates(visits: List[str]) -> pd.Series[List[str], List[date]]:
    new_visits = []
    dates = []
    for visit in visits:
        new_visit = visit.split("Fecha: ")[1]
        try:
            date_str, new_visit = new_visit[:9], new_visit[9:]
            d = date.strptime(date_str, "%d%b%Y")
        except ValueError:
            d = None
        new_visits.append(new_visit)
        dates.append(d)
    return pd.Series([new_visits, impute_missing_dates(dates)])

# %%
df[['new_visits', 'dates']] = df['visits'].apply(pop_dates)

# %%
df
# Out:
#               person_id  label  \
# 0    PATTERN_M-00314259      1
# 1    PATTERN_M-00337378      1
# 2    PATTERN_M-00710666      1
# 3    PATTERN_M-01649881      2
# 4    PATTERN_M-01756648      1
# ..                  ...    ...
# 163  PATTERN_M-03510507      0
# 164  PATTERN_M-02301744      0
# 165  PATTERN_M-02021706      0
# 166  PATTERN_M-03657032      0
# 167  PATTERN_M-03188178      0
#
#                                                 visits  num_visits  \
# 0    [Fecha: 16oct2009 OBSERVACIONES: ESPECIMEN: B0...           8
# 1    [Fecha: 14nov2018 ANOTACIONES: Enfermedad de C...           2
# 2    [Fecha: 08mar2017 PROBLEMAS DE SALUD: CONSULTA...           9
# 3    [Fecha: 15jul2013 ANOTACIONES: CONSULTA 15.7.1...          22
# 4    [Fecha: 12sep2019 ANOTACIONES: Enfermedad de C...         105
# ..                                                 ...         ...
# 163  [Fecha: 02sep2015 OBSERVACIONES: Problema Actu...          25
# 164  [Fecha: 17may2012 OBSERVACIONES: ESPECIMEN: C1...          18
# 165  [Fecha: 25may2021 PROBLEMAS DE SALUD: Antecede...          22
# 166  [Fecha: 21may2017 OBSERVACIONES: Motivo de Ing...          21
# 167  [Fecha: 22nov2014 OBSERVACIONES: Hematies: 4.8...          25
#
#      visits_num                                         new_visits  \
# 0             8  [ OBSERVACIONES: ESPECIMEN: B0922962 FECHA ENT...
# 1             2  [ ANOTACIONES: Enfermedad de Chagas en posible...
# 2             9  [ PROBLEMAS DE SALUD: CONSULTA GENÉRICA GINECO...
# 3            22  [ ANOTACIONES: CONSULTA 15.7.13 Mejoria con ci...
# 4            40  [ ANOTACIONES: Enfermedad de Chagas en fase cr...
# ..          ...                                                ...
# 163          25  [ OBSERVACIONES: Problema Actual: Supuracion O...
# 164          18  [ OBSERVACIONES: ESPECIMEN: C1214844 FECHA ENT...
# 165          22  [ PROBLEMAS DE SALUD: Antecedentes Personales ...
# 166          21  [ OBSERVACIONES: Motivo de Ingreso: Ojo rojo d...
# 167          25  [ OBSERVACIONES: Hematies: 4.87 Hemoglobina: 1...
#
#                                                  dates
# 0    [2009-10-16, 2015-06-08, 2015-06-29, 2017-03-1...
# 1                             [2018-11-14, 2018-12-12]
# 2    [2017-03-08, 2017-04-24, 2018-02-01, 2018-06-1...
# 3    [2013-07-15, 2013-12-12, 2014-01-08, 2014-01-2...
# 4    [2019-09-12, 2019-11-18, 2020-02-11, 2020-02-2...
# ..                                                 ...
# 163  [2015-09-02, 2015-12-20, 2016-05-12, 2016-11-0...
# 164  [2012-05-17, 2017-07-02, 2020-05-12, 2020-06-1...
# 165  [2021-05-25, 2021-11-22, 2021-12-16, 2021-12-2...
# 166  [2017-05-21, 2019-04-24, 2021-03-28, 2021-04-0...
# 167  [2014-11-22, 2015-02-25, 2015-03-04, 2015-03-0...
#
# [168 rows x 7 columns]

# %%
import pandas as pd
import ast

df = pd.read_csv("data/data_dir/cleaned_chagas_data.csv")
df['visits'] = df['visits'].apply(ast.literal_eval)
df['visits'] = df.apply(lambda row: row['visits'] if row['num_visits'] <= 40 else row['visits'][-40:], axis=1) # if there are more than 40 visits, take only the last 40
df.rename(columns={'clasificacion_diag': 'label'}, inplace=True)

# %%
visits_df.apply(lambda x: x.startswith('Fecha: ')).value_counts()
# Out:
# visits
# True    2569
# Name: count, dtype: int64

# %%
"Fecha: 22jan2010ñlkjj".split("Fecha: ")[1][:9]
# Out:
# '22jan2010'

# %%
fechas = visits_df.apply(lambda x: x.split("Fecha: ")[1][:9])

# %%
from torch import log1p

# %%
log1p(torch.tensor([0,1,32,45]))
# Out:
# tensor([0.0000, 0.6931, 3.4965, 3.8286])

# %%
fecha
# Out:
# '. OBSERVA'

# %%
for fecha in fechas:
    try:
        datetime.strptime(fecha, "%d%b%Y")
    except ValueError:
        print(fecha)
# Out:
# . OBSERVA
# . OBSERVA
# . OBSERVA
# . OBSERVA
# . OBSERVA
# . OBSERVA

# %%
from datetime import datetime

date = '05mar2021'
datetime.strptime(date, "%d%b%Y")
# Out:
# datetime.datetime(2021, 3, 5, 0, 0)

# %%
dates = visits_df.apply(lambda x: datetime.strptime(x.split("Fecha: ")[1][:9], "%d%b%Y"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 dates = visits_df.apply(lambda x: datetime.strptime(x.split("Fecha: ")[1][:9], "%d%b%Y"))
#
# File ~/.conda/envs/chagas_pred/lib/python3.14/site-packages/pandas/core/series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
#    4942         kwargs=kwargs,
# -> 4943     ).apply()
#
# File ~/.conda/envs/chagas_pred/lib/python3.14/site-packages/pandas/core/apply.py:1422, in SeriesApply.apply(self)
#    1419     return self.apply_compat()
#    1421 # self.func is Callable
# -> 1422 return self.apply_standard()
#
# File ~/.conda/envs/chagas_pred/lib/python3.14/site-packages/pandas/core/apply.py:1502, in SeriesApply.apply_standard(self)
#    1496 # row-wise access
#    1497 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1498 # we need to give `na_action="ignore"` for categorical data.
#    1499 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1500 #  Categorical (GH51645).
#    1501 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1502 mapped = obj._map_values(
#    1503     mapper=curried, na_action=action, convert=self.convert_dtype
#    1504 )
#    1506 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1507     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1508     #  See also GH#25959 regarding EA support
#    1509     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/.conda/envs/chagas_pred/lib/python3.14/site-packages/pandas/core/base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/.conda/envs/chagas_pred/lib/python3.14/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[44], line 1, in <lambda>(x)
# ----> 1 dates = visits_df.apply(lambda x: datetime.strptime(x.split("Fecha: ")[1][:9], "%d%b%Y"))
#
# File ~/.conda/envs/chagas_pred/lib/python3.14/_strptime.py:815, in _strptime_datetime_datetime(cls, data_string, format)
#     812 def _strptime_datetime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     813     """Return a datetime instance based on the input string and the
#     814     format string."""
# --> 815     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     816     tzname, gmtoff = tt[-2:]
#     817     args = tt[:6] + (fraction,)
#
# File ~/.conda/envs/chagas_pred/lib/python3.14/_strptime.py:555, in _strptime(data_string, format)
#     553 found = format_regex.match(data_string)
#     554 if not found:
# --> 555     raise ValueError("time data %r does not match format %r" %
#     556                      (data_string, format))
#     557 if len(data_string) != found.end():
#     558     raise ValueError("unconverted data remains: %s" %
#     559                       data_string[found.end():])
#
# ValueError: time data '. OBSERVA' does not match format '%d%b%Y'

# %%
df.visits.iloc[10]
# Out:
# ["Fecha: 05mar2021 ANOTACIONES: Vuelve a citarse de nuevo porque nota inflamacion, sensacion de calor y oscurecimiento de lesiones de forma intermitente que dura unos 3 dias y remite espontaneamente. La ulitma vez hace una semana. Refiere mas molestias desde que usa mascarilla y con cambios de temperatura. Mujer de 51 anos, trasplantada hepatica el dia 17/04/2019 en relacion con hepatitis autoinmune overlap CEP, con AP de LES y EII. Enfermedad de injerto contra huesped aguda con afectacion mucocutanea severa tipo NET en 2019, resuelta. Tratamiento habitual: Tacrolimus 5 mg, Famotidina, Dapsona, Prednisona 5 mg, Dolquine, Mesalazina, Aciclovir, Amlodipino. EPO alfa A la exploracion presenta maculas marrones calras en zona lateral de mejillas y ligero eritema en mejillas y zona cejas sin descamacion. Unas pintadas. JC. Flushing/cuperosis. Tambien el tacrolimus puede aumentar la fotosensibilidad. Plan. Se recomiendo no usar esmalte unas Usar mascarilla de tela bajo la mascarilla quir'ruga o FFFP2 Rosacure fast Se cita en consuta de eccema para valoracion DIAGNÓSTICOS Y PROCEDIMIENTOS: Arañas vasculares Melasma OBSERVACIONES: Antecedentes Familiares: . Antecedentes Personales: -Somaticos: no alergias medicamentosas conocidas. DLP. LES con afectacion articular, dermatologica y hematologica. Enfermedad de Crohn. TBC latente tratada. Gamapatia monoclonal. Anemia ferropenica. Vasculitis leucocitoclastica. Gastritis Cronica. Ulceras perianales secundarias a herpes virus tipo 2 resueltas. Enfermedad de Chagas en fase cronica indeterminada. Osteopenia multifactorial. Insuficiencia mitral leve. Pancitopenia por hiperesplenismo. Colangitis de repeticion. IQ: conizacion cervical en 2016, transplante hepatico en 2019 por cirrosis hepatica en contexto de hepatitis autoinmune, incluyendo debut de enfermedad de injerto contra huesped (EICH). -Psiquiatricos: diagnosticada de trastorno adaptativo, describiendose en informes clinica depresiva desde 2013 tras el fallecimiento de la madre. Realizo seguimiento en CSM Usera en 2015-2016, siendo dada de alta. Valorada en julio de 2019 a traves de nuestro servicio de interconsulta hospitalaria de Psiquiatria durante ingreso a cargo de Cirugia General y Digestiva. No ingresos psiquiatricos previos. Tratamiento en el pasado con Paroxetina y Escitalopram, refiriendo buen efecto clinico de ambos. -Antecedentes familiares psiquiatricos: niega. -Situacion socio-familiar: natural de Bolivia, en Espana desde 2005. Divorciada, 2 hijos y otro en acogida, la segunda de 5 hermanos (la tercera fallecida, el mayor en paradero desconocido), padres fallecidos. Convive con una amiga. Actualmente de baja laboral temporal, pendiente de valorar incapacidad laboral permanente. -Habitos toxicos: niega. Tratamiento: Dolquine, Prednisona, Claversal, Advagraf, Aciclovir, Famotidina, Calcio carbonato, Hidroxicloroquina, Eritropoyetina semanal. Antecedentes obstetrico quirurgicos: . Antecedentes profesionales: . Situacion social Convivencia: . Motivo de alta formulario: -1 Fecha de llegada a Espana: . Fecha ultimo viaje a pais origen: . Indicaciones al Alta: Sin tratamiento especifico por nuestra parte en este momento Intolerancia: . Pais de origen: . Problema Actual: Nos remiten a paciente de 44 anos con antecedentes de lupus eritematoso sistemico en seguimiento por el servicio de Reumatologia. Presenta areas de hiperpigmentacion marronacea en cara (melasma?) asi como unas aranas vasculares micro/milimetricas en el area del escote en escaso numero. Tras la valoracion de las lesiones vasculares en una paciente de fototipo IV-V no creemos que sea beneficioso aplicar terapia laser en este caso. RAZA_EST: Hispana Situacion fisica: . Situacion mental: .",
#  'Fecha: 10mar2021 ANOTACIONES: 10 de marzo de 2021: l Tratamiento: Claversal 4 al dia, famotidina 40 mg 1-0-1, Advagraf 5 mg/dia, Dapsona un comprimido la dia, prednisona 5 mg/d por la manana, Deltius mensual, calcio, azatioprina 25 mg /dia, EPO cada 15 dias. a paciente esta bien en general, pero refiere sensacion de distension abdominal, que provoca molestias pero no dolor. refiere ardor epigastrico y retroesternal, que comenta no tenia previamente. Lo que tenia previamente es sensacion de salivacion espesa. No nauseas ni vomitos. No disfagia ni odinofagia. A veces nota dolor el centro del torax al pasar la comida y luego s ele pasa. No tiene tos matutina. No perdida de peso ni apetito. No sangrado. CON IBP mejoro pero hubo que suspenderlo por pancitopenia. esta con famotidina de 40 mg manana y noche. Con esta medicacion ha mejorado. Distingue esta sintomatologia de la distension abdominal que relaciona con eventracion post QX abdominal. Esto ha sido valorado por el equipo de TX. De la EII esta asintomatica. Desde que esta con Dapsona nota coloracion oscura /verdosa de las heces esta en ficha tecnica Exploracion: eventracion postQX. No masas ni megalias. No dolor abdominal. AS: Hb11, 2, VCM 103, 3000 leucocitos, aumento leve de GGT. resto dentro de normalidad. CF: <22. JC: 1.- EII del colon en remision con mesalazina 2.- Adenomas tubulares. 3.- THO por CEP con EICH controlada e infeccion diseminada por CMV. Actualmente resuelto. 4.- Clinica sugestiva de ERGE sin datos de alharma con respuesta a famotidina (pancitopenia con omeprazol9 5.- previos plan: 1.- Seguir con famotidina 40 mg 1-0-1 2.- dieta y medidas antirreflujo. 3.- Pido eco abdominal y colonoscopia de cribado por tener CEP, THO y EII 4.- revision en mayo y si no hay mejoria de la clinica de RGE pedire manometria y pH metria. Tiene gastro de noviembre de 20219 sin lesiones macroscopicas ni microscopicas. DIAGNÓSTICOS Y PROCEDIMIENTOS: Enteritis regional Adenomas tubulares de bajo grado y pólipo hiperplásico extripados en colonoscopia 2015 Ci hepatica (overlap HAI+CEP). Tx hepatico el 18 de abril de 2019. GHVD controlado actualmente LES CON AFECTACION CUTANEA Y HEMATOLOGICA actualmente controlado Infeccion por COVID-19 en septiembre de 2020 Adenoma tubular d ebajo grado eb colonoscopia + cromoendoscopia de 2020 Enfermedad por Citomegalovirus (2019) Enfermedad por CMV diseminado con afectacion del colon y panctopenia (2019) dispespia con compeente de RGe sin datos de alarrma OBSERVACIONES: Antecedentes Familiares: . Antecedentes Personales: -Somaticos: no alergias medicamentosas conocidas. DLP. LES con afectacion articular, dermatologica y hematologica. Enfermedad de Crohn. TBC latente tratada. Gamapatia monoclonal. Anemia ferropenica. Vasculitis leucocitoclastica. Gastritis Cronica. Ulceras perianales secundarias a herpes virus tipo 2 resueltas. Enfermedad de Chagas en fase cronica indeterminada. Osteopenia multifactorial. Insuficiencia mitral leve. Pancitopenia por hiperesplenismo. Colangitis de repeticion. IQ: conizacion cervical en 2016, transplante hepatico en 2019 por cirrosis hepatica en contexto de hepatitis autoinmune, incluyendo debut de enfermedad de injerto contra huesped (EICH). -Psiquiatricos: diagnosticada de trastorno adaptativo, describiendose en informes clinica depresiva desde 2013 tras el fallecimiento de la madre. Realizo seguimiento en CSM Usera en 2015-2016, siendo dada de alta. Valorada en julio de 2019 a traves de nuestro servicio de interconsulta hospitalaria de Psiquiatria durante ingreso a cargo de Cirugia General y Digestiva. No ingresos psiquiatricos previos. Tratamiento en el pasado con Paroxetina y Escitalopram, refiriendo buen efecto clinico de ambos. -Antecedentes familiares psiquiatricos: niega. -Situacion socio-familiar: natural de Bolivia, en Espana desde 2005. Divorciada, 2 hijos y otro en acogida, la segunda de 5 hermanos (la tercera fallecida, el mayor en paradero desconocido), padres fallecidos. Convive con una amiga. Actualme ...
#  'Fecha: 14apr2021 ANOTACIONES: M. Interna interconsultas . Consulta 14/4/2021 La paciente se encuntra bien, estuvo en consulta de M.Digetsivo por epigastralgia le mantuvieron la famitidina y le insistieron en la dieta y las medidas antirreflujo, la paciente refiere que ha mejorado. Tiene cita en Mayo para ver si hace falta pedir una PHmetria. Por otro lado dice que desde Marzo comenzo con tos seca con disnea asociada, le han hecho PCR de COVID en 2 ocasiones que ha sido negativa. Su MAP le ha pautado salbutamol y refiere que ha mejorado. Analitica: Vitamina D (25-OH-Vitamina D) 21.3 ng/ml, Colesterol 164 mg/dl, LDL (estimacion Friedewald) 69 mg/dl, Vitamina B12 623.60 pg/ml, Acido Folico 7.3 ng/ml, Proteina C Reactiva 0.15 mg/dl, Creatinina 1.14 mg/dl, Cloro 111 mEq/l, ALT (GPT) 23 U/l, AST (GOT) 24 U/l, Gamma-GT 62 U/l, Fosfatasa Alcalina 77 U/l, Ferritina 201 ng/ml, Hierro 127 ?g/dl, Transferrina 185 mg/dl, TIBC 261 ?g/dl, % Saturacion Transferrina 48.8 %, Hemoglobina 11.2 g/dl, Plaquetas 94 x1000/?l, Leucocitos 3.3 x1000/?l, Neutrofilos 1.9 x1000/?l, Neutrofilos % 56.9 %, Linfocitos 1.1 x1000/?l, Tiempo de Protrombina 13.1 sec, INR (Laboratorio) 1.15 , TTPa 28 sec, Plan- hago receta de dapsona y EPO - pido espirometria y RXTX. DIAGNÓSTICOS Y PROCEDIMIENTOS: EICH agudo tipo NET tras tx hepático con afectación cutanea, medular y GI Hipocalcemia, hipomagensemia, hipofosofremia y ehipopotasemia e hiponatremia 2º a eEICH y luego a foscarnet Enfermedad por Citomegalovirus Trasplante hepático por Cirrosis hepática secundaria overlap HAI/CEP Enteritis regional LES CON AFECTACION CUTANEA Y HEMATOLOGICA en tratamiento con esteroides y azatiorpina. Infección genirtal por Herpes tipo 2 OBSERVACIONES: Antecedentes Familiares: . Antecedentes Personales: -Somaticos: no alergias medicamentosas conocidas. DLP. LES con afectacion articular, dermatologica y hematologica. Enfermedad de Crohn. TBC latente tratada. Gamapatia monoclonal. Anemia ferropenica. Vasculitis leucocitoclastica. Gastritis Cronica. Ulceras perianales secundarias a herpes virus tipo 2 resueltas. Enfermedad de Chagas en fase cronica indeterminada. Osteopenia multifactorial. Insuficiencia mitral leve. Pancitopenia por hiperesplenismo. Colangitis de repeticion. IQ: conizacion cervical en 2016, transplante hepatico en 2019 por cirrosis hepatica en contexto de hepatitis autoinmune, incluyendo debut de enfermedad de injerto contra huesped (EICH). -Psiquiatricos: diagnosticada de trastorno adaptativo, describiendose en informes clinica depresiva desde 2013 tras el fallecimiento de la madre. Realizo seguimiento en CSM Usera en 2015-2016, siendo dada de alta. Valorada en julio de 2019 a traves de nuestro servicio de interconsulta hospitalaria de Psiquiatria durante ingreso a cargo de Cirugia General y Digestiva. No ingresos psiquiatricos previos. Tratamiento en el pasado con Paroxetina y Escitalopram, refiriendo buen efecto clinico de ambos. -Antecedentes familiares psiquiatricos: niega. -Situacion socio-familiar: natural de Bolivia, en Espana desde 2005. Divorciada, 2 hijos y otro en acogida, la segunda de 5 hermanos (la tercera fallecida, el mayor en paradero desconocido), padres fallecidos. Convive con una amiga. Actualmente de baja laboral temporal, pendiente de valorar incapacidad laboral permanente. -Habitos toxicos: niega. Tratamiento: Dolquine, Prednisona, Claversal, Advagraf, Aciclovir, Famotidina, Calcio carbonato, Hidroxicloroquina, Eritropoyetina semanal. Antecedentes obstetrico quirurgicos: . Antecedentes profesionales: . Situacion social Convivencia: . Motivo de alta formulario: -1 Dieta texto libre: DIETA SIN LACTOSA Fecha de llegada a Espana: . Fecha ultimo viaje a pais origen: . Indicaciones al Alta: - La paciente debe continuar en tratamiento profliactico para el Pn. Jirovecci con Dapsona de forma indefenida. Intolerancia: . Motivo de Ingreso: Seguimiento Pais de origen: . Prescripcion al alta: suspendo Amlodipino Resto tto sin cambios - TACROLIMUS 5 MG 1-0-0 - FA ...
#  'Fecha: 22apr2021 ANOTACIONES: 22/04/2021 Paciente con maculas hiperpigmentadas en pomulos de 3 anos de evolucion. Empeoran en verano y se aclaraban parcialmente en invierno. El ano pasado, coincidiendo con el periodo de confinamiento, las lesiones desaparecieron totalmente Desde mayo 2020 vuelven a aparecer lesiones similares, con periodos de enrojecimiento y escozor en pomulos, y ambas mejillas. Son placas marronaceas de morfologia reticulada, bordes imprecisos y superficie lisa. En cara usa 2 fotoprotectores de Anthelios y Bioderma, una crema hidradante Sohu, limpiiadora y tonico de Sesderma. Colonia en la ropa. Aceite de rosa mosqueta en curerpo J. clinico: melasma vs melanosis de Rihel Plan: Retiro todos los cosmeticos Fotoproteccion con filtro solar con filtros fisicos de AVENE Cito para fotoparche con bateria estandar, fotoalergenos y propios DIAGNÓSTICOS Y PROCEDIMIENTOS: Arañas vasculares Melasma vs melanosis de Rielh Fotoparche OBSERVACIONES: Antecedentes Familiares: . Antecedentes Personales: -Somaticos: no alergias medicamentosas conocidas. DLP. LES con afectacion articular, dermatologica y hematologica. Enfermedad de Crohn. TBC latente tratada. Gamapatia monoclonal. Anemia ferropenica. Vasculitis leucocitoclastica. Gastritis Cronica. Ulceras perianales secundarias a herpes virus tipo 2 resueltas. Enfermedad de Chagas en fase cronica indeterminada. Osteopenia multifactorial. Insuficiencia mitral leve. Pancitopenia por hiperesplenismo. Colangitis de repeticion. IQ: conizacion cervical en 2016, transplante hepatico en 2019 por cirrosis hepatica en contexto de hepatitis autoinmune, incluyendo debut de enfermedad de injerto contra huesped (EICH). -Psiquiatricos: diagnosticada de trastorno adaptativo, describiendose en informes clinica depresiva desde 2013 tras el fallecimiento de la madre. Realizo seguimiento en CSM Usera en 2015-2016, siendo dada de alta. Valorada en julio de 2019 a traves de nuestro servicio de interconsulta hospitalaria de Psiquiatria durante ingreso a cargo de Cirugia General y Digestiva. No ingresos psiquiatricos previos. Tratamiento en el pasado con Paroxetina y Escitalopram, refiriendo buen efecto clinico de ambos. -Antecedentes familiares psiquiatricos: niega. -Situacion socio-familiar: natural de Bolivia, en Espana desde 2005. Divorciada, 2 hijos y otro en acogida, la segunda de 5 hermanos (la tercera fallecida, el mayor en paradero desconocido), padres fallecidos. Convive con una amiga. Actualmente de baja laboral temporal, pendiente de valorar incapacidad laboral permanente. -Habitos toxicos: niega. Tratamiento: Dolquine, Prednisona, Claversal, Advagraf, Aciclovir, Famotidina, Calcio carbonato, Hidroxicloroquina, Eritropoyetina semanal. Antecedentes obstetrico quirurgicos: . Antecedentes profesionales: . Situacion social Convivencia: . Motivo de alta formulario: 11 Fecha de alta formulario: 22/04/2021 Fecha de llegada a Espana: . Fecha ultimo viaje a pais origen: . Hora de alta formulario: 11:50 Indicaciones al Alta: Sin tratamiento especifico por nuestra parte en este momento Intolerancia: . Pais de origen: . Problema Actual: Nos remiten a paciente de 44 anos con antecedentes de lupus eritematoso sistemico en seguimiento por el servicio de Reumatologia. Presenta areas de hiperpigmentacion marronacea en cara (melasma?) asi como unas aranas vasculares micro/milimetricas en el area del escote en escaso numero. Tras la valoracion de las lesiones vasculares en una paciente de fototipo IV-V no creemos que sea beneficioso aplicar terapia laser en este caso. RAZA_EST: Hispana Situacion fisica: . Situacion mental: . Evolucion Datos Laboratorio: 213297321 Hematies: 3.98 Hemoglobina: 13.0 Hematocrito: 39.9 HCM: 32.7 VCM: 100.2 CHCM: 32.6 RDW: 15.2 Plaquetas: 126 VPM: 10.5 Leucocitos: 4.6 Neutrofilos: 3.2 Neutrofilos %: 68.2 Linfocitos: 1.1 Linfocitos %: 23.3 Monocitos: 0.3 Monocitos %: 6.5 Eosinofilos: 0.1 Eosinofilos %: 1.7 Basofilos: 0.0 Basofilos %: 0.3 Tiempo de Protrombina: 13.1 Actividad de Pro ...
#  'Fecha: 26apr2021 ANOTACIONES: Mujer de 52 anos con: * THO Cirrosis hepatica secundaria a sd de overlap HAI/CEP 18 Abril 2019 - Ingreso por la sospecha de SSJ en relacion con tacrolimus se cambia a MMF y everolimus, pero ante el deterioro de la funcion renal y ante la evolucion y las pruebas complementarias que es mas compatible con EICH se cambia a CSA y azatioprina. Y posteriormente se suspende azatioprina y se mantiene solo CSA con niveles fluctuantes por la interaccion con el posaconazol pero sin datos de rechazo. * LES con afectacion cutanea hematologica * EII tipo Crohn * Alteracion metabolismo del calcio secundario a EICH y foscarnet ** Informe verbal de BHP (26/11/19): RA grado I en fase postratamiento (en evolucion). Importante inflamacion en el lobulillo compatible bien con afectacion de la VBP vs recidiva de su enfermedad de base. - IS: ciclosporina 175 cada 12 h + Prednisona 5 mg cada 24hs. - BHP (26/11/19): Biopsia hepatica percutanea correspondiente a injerto en el dia 218 despues de trasplante con lesion ductal y leve endotelitis que sugiere rechazo agudo celular en situacion post tratamiento previo, que en este momento corresponderia con un grado 1-leve. Ver comentario. Comentario: En el momento actual la inflamacion correspondiente al rechazo y la endotelitis son leves, pero debe considerarse que la biopsia se tomo despues de una subida de la inmunosupresion y bajada de las transaminasas. Existe un componente de inflamacion lobulillar y central que puede ser atribuible al rechazo pero que recomienda seguimiento por la posible evolucion a una hepatitis de mecanismo inmune dado los antecedentes del paciente. - IHQ: Negativa para detectar citomegalovirus Se presento en sesion multidisciplinar de trasplante hepatico el 13/01/2020 (M.Interna, Enf infecciosas, Dermatologia, Reumatologia, Hematologia, Alergia, MAD, UCI y Cirugia): - Parece razonable descartar el Steven Jhonson) por lo que se podria volver a utilizar el tacrolimus. - El seguimiento del EICH se considera que debe ser clinico sin dar ni saber claramente el valor del quimerismo. - Se debe realizar un estudio de su anemia. - En seguimiento por MAD por EII, pendiente de revision proximamente. - Recientemente evaluada por psiquiatria: Trastorno adaptativo mixto con sintomas de ansiedad y depresion sobre base de trastorno ansioso-depresivo recurrente: Escitalopram y Lorazepam. IS con Advagraf 5 mg (niv 6) y prednisona 5 mg/d. Perfil hepatico sin cambios. No citolisis. Solo GGT de 68, en mejoria. Cr 1,3 estable. Citopenias controladas. Mejoria de Hb a 13. con tratamiento pautado por medicina interna. Tiene algo de tos y esta pendiente de espirometria y Rx de torax con revision en interna. Le han puesto la primera dosis de vacuna para Covid19 (moderna) el 15/04. PLAN: Dejo tratamiento sin cambios. Revision antes del verano. Se hace control de medicacion. La paciente se encuentra bien, sin incidencias. analitica normal, cita en 2 meses. se da volante de analitica para siguiente consulta DIAGNÓSTICOS Y PROCEDIMIENTOS: Síndrome overlap hepático Enfermedad de injertohepático) contra huésped Trasplante hepático OBSERVACIONES: Antecedentes Familiares: . Antecedentes Personales: -Somaticos: no alergias medicamentosas conocidas. DLP. LES con afectacion articular, dermatologica y hematologica. Enfermedad de Crohn. TBC latente tratada. Gamapatia monoclonal. Anemia ferropenica. Vasculitis leucocitoclastica. Gastritis Cronica. Ulceras perianales secundarias a herpes virus tipo 2 resueltas. Enfermedad de Chagas en fase cronica indeterminada. Osteopenia multifactorial. Insuficiencia mitral leve. Pancitopenia por hiperesplenismo. Colangitis de repeticion. IQ: conizacion cervical en 2016, transplante hepatico en 2019 por cirrosis hepatica en contexto de hepatitis autoinmune, incluyendo debut de enfermedad de injerto contra huesped (EICH). -Psiquiatricos: diagnosticada de trastorno adaptativo, describiendose en informes clinica depresiva desde 2013 tras el fallecimiento de la ...
#  'Fecha: 06may2021 OBSERVACIONES: Evolucion Datos Laboratorio: 213304542 Vitamina D (25-OH-Vitamina D): Comentario (R) Glucosa (or): Negativo Proteinas (or): Negativo Bilirrubina (or): Negativo Urobilinogeno (or): 0.2 pH (or): 6.0 Densidad (or): 1013 Cetonas (or): Negativo Sangre (or): Negativo Nitritos (or): Negativo Hematies: 4.02 Hemoglobina: 13.1 Hematocrito: 39.6 HCM: 32.5 VCM: 98.5 CHCM: 33.0 RDW: 14.9 Plaquetas: 110 VPM: 11.4 Leucocitos: 3.3 Neutrofilos: 2.0 Neutrofilos %: 59.9 Linfocitos: 1.1 Linfocitos %: 32.1 Monocitos: 0.2 Monocitos %: 5.6 Eosinofilos: 0.1 Eosinofilos %: 1.9 Basofilos: 0.0 Basofilos %: 0.5 Leucocitos (or): + 1 SEDIMENTO URINARIO:: * Sedim-Bacteriuria: Escasa Sedim-Celulas epiteliales: Escasas Sedim-Leucocitos: 1 Sedim-Hematies: 1 Indice de Hemolisis: 30 Indice de Lipemia: 9 Indice de Ictericia13: 1 Glucosa: 82 Creatinina: 1.09 Filtrado Glomerular (ckd-epi): 59 Proteinas Totales: 6.9 Albumina: 4.8 Calcio: 9.0 Fosforo: 3.9 ALT (GPT): 24 AST (GOT): 27 Gamma-GT: 59 Fosfatasa Alcalina: 93 Bilirrubina: 0.3 Colesterol: 167 Trigliceridos: 118 LDL (estimacion Friedewald): 81 HDL: 62 Acido Urico: 4.9 Colesterol-No HDL: 105.0 Relacion LDL/HDL: 1.31 Relacion Colesterol/HDL: 2.69 Proteina C Reactiva: 0.21 Factor Reumatoide: 8 Ac. Anti Nucleares-IFI: Comentario (R) Paratohormona (PTH): 74.0 C3: 73.10 C4: 17.30',
#  'Fecha: 19may2021 ANOTACIONES: 19/05/2021: acude a revision. Tras ultima revision, fue valorada en Urgencias, no se confirmo infiltrado neumonico pero si tractos cicatriciales en LSD que ya presentaba. En este tiempo, ademas se ha pautado famotidina por clinica de RGE y broncodilatadores por persistencia de tos seca. Esta pendiente de espirometria y nueva rx torax. Su principal queja es la tos seca y ha tenido artralgias sin artritis en manos. No fiebre. No otra sintomatologia. Ya ha recibido las dos dosis de vacuna Covid (Moderna) con buena tolerancia. EF: ACP normal. TA 115/76. No adenopatias. No artritis. No edemas Refiere dolor a punta de dedo a la palpacion abdominal en HCD pero no se palpa masas ni megalias. Plan: no modifico tto. DIAGNÓSTICOS Y PROCEDIMIENTOS: Lupus eritematoso relativo a sistema Displasia cérvix, VPH positivo Colangiopatía autoinmune/cirrosis hepática Enfermedad inflamatoria tipo Crohn Osteoporosis Tx hepático Serología positiva Chagas OBSERVACIONES: Antecedentes Familiares: . Antecedentes Personales: -Somaticos: no alergias medicamentosas conocidas. DLP. LES con afectacion articular, dermatologica y hematologica. Enfermedad de Crohn. TBC latente tratada. Gamapatia monoclonal. Anemia ferropenica. Vasculitis leucocitoclastica. Gastritis Cronica. Ulceras perianales secundarias a herpes virus tipo 2 resueltas. Enfermedad de Chagas en fase cronica indeterminada. Osteopenia multifactorial. Insuficiencia mitral leve. Pancitopenia por hiperesplenismo. Colangitis de repeticion. IQ: conizacion cervical en 2016, transplante hepatico en 2019 por cirrosis hepatica en contexto de hepatitis autoinmune, incluyendo debut de enfermedad de injerto contra huesped (EICH). -Psiquiatricos: diagnosticada de trastorno adaptativo, describiendose en informes clinica depresiva desde 2013 tras el fallecimiento de la madre. Realizo seguimiento en CSM Usera en 2015-2016, siendo dada de alta. Valorada en julio de 2019 a traves de nuestro servicio de interconsulta hospitalaria de Psiquiatria durante ingreso a cargo de Cirugia General y Digestiva. No ingresos psiquiatricos previos. Tratamiento en el pasado con Paroxetina y Escitalopram, refiriendo buen efecto clinico de ambos. -Antecedentes familiares psiquiatricos: niega. -Situacion socio-familiar: natural de Bolivia, en Espana desde 2005. Divorciada, 2 hijos y otro en acogida, la segunda de 5 hermanos (la tercera fallecida, el mayor en paradero desconocido), padres fallecidos. Convive con una amiga. Actualmente de baja laboral temporal, pendiente de valorar incapacidad laboral permanente. -Habitos toxicos: niega. Tratamiento: Dolquine, Prednisona, Claversal, Advagraf, Aciclovir, Famotidina, Calcio carbonato, Hidroxicloroquina, Eritropoyetina semanal. Antecedentes obstetrico quirurgicos: . Antecedentes profesionales: . Situacion social Convivencia: . Motivo de alta formulario: 11 Exploracion: ACP: normal. No sibilancias, no crepitantes. No adenopatias. No ulceras orales. No Raynaud. No artritis en la exploracion. No edemas. Aranas vasculares en torax. Fecha de alta formulario: 19/05/2021 Fecha de llegada a Espana: . Fecha ultimo viaje a pais origen: . Hora de alta formulario: 15:30 Indicaciones al Alta: 5 meses con analitica y DXA En caso de cualquier complicacion o duda relativa a su enfermedad puede contactar a traves del correo:reuma.pacientes.hdoc@salud.madrid.org O en el telefono 609676124 Se remite a Urgencias para realizar Rx torax y monitorizar insuficiencia respiratoria. Ha consulta en Urgencias el dia 1/11 por tos y sensacion de disnea. La auscultacion es normal pero SatO2 88-90%. Se recomienda ademas avisar a cirugia (tx hepatico) Intolerancia: . Motivo de Ingreso: Seguimiento de lupus eritematoso sistemico. Pais de origen: . Prescripcion al alta: Advagraf 5 mg/24 h vo Prednisona 5 mg/24 h vo - EPO alfa 10.000 1 vez a la semana - FAMOTIDINA 40 MG /12 HORAS - DAPSONA 100 MG 1 COMPRIMIDO al dia - CALCIO CARBONATO 2.500 MG (1.000 MG CA)/VITAMINA D 1000: 1 sobre CADA 24 HORAS ...
#  'Fecha: 21may2021 ANOTACIONES: Telefono no contesta Cito presencial (2019 Julio orto) OBSERVACIONES: Antecedentes Familiares: . Antecedentes Personales: -Somaticos: no alergias medicamentosas conocidas. DLP. LES con afectacion articular, dermatologica y hematologica. Enfermedad de Crohn. TBC latente tratada. Gamapatia monoclonal. Anemia ferropenica. Vasculitis leucocitoclastica. Gastritis Cronica. Ulceras perianales secundarias a herpes virus tipo 2 resueltas. Enfermedad de Chagas en fase cronica indeterminada. Osteopenia multifactorial. Insuficiencia mitral leve. Pancitopenia por hiperesplenismo. Colangitis de repeticion. IQ: conizacion cervical en 2016, transplante hepatico en 2019 por cirrosis hepatica en contexto de hepatitis autoinmune, incluyendo debut de enfermedad de injerto contra huesped (EICH). -Psiquiatricos: diagnosticada de trastorno adaptativo, describiendose en informes clinica depresiva desde 2013 tras el fallecimiento de la madre. Realizo seguimiento en CSM Usera en 2015-2016, siendo dada de alta. Valorada en julio de 2019 a traves de nuestro servicio de interconsulta hospitalaria de Psiquiatria durante ingreso a cargo de Cirugia General y Digestiva. No ingresos psiquiatricos previos. Tratamiento en el pasado con Paroxetina y Escitalopram, refiriendo buen efecto clinico de ambos. -Antecedentes familiares psiquiatricos: niega. -Situacion socio-familiar: natural de Bolivia, en Espana desde 2005. Divorciada, 2 hijos y otro en acogida, la segunda de 5 hermanos (la tercera fallecida, el mayor en paradero desconocido), padres fallecidos. Convive con una amiga. Actualmente de baja laboral temporal, pendiente de valorar incapacidad laboral permanente. -Habitos toxicos: niega. Tratamiento: Dolquine, Prednisona, Claversal, Advagraf, Aciclovir, Famotidina, Calcio carbonato, Hidroxicloroquina, Eritropoyetina semanal. Antecedentes obstetrico quirurgicos: . Antecedentes profesionales: . Situacion social Convivencia: . Motivo de alta formulario: -1 Fecha de llegada a Espana: . Fecha ultimo viaje a pais origen: . Intolerancia: . Pais de origen: . RAZA_EST: Hispana Situacion fisica: . Situacion mental: .',
#  'Fecha: 25may2021 OBSERVACIONES: IMAGEN DE TORAX, P-A Y LAT Evolucion Datos Laboratorio: 411048805 pH Arterial: 7.38 pCO2 Arterial: 31 pO2 Arterial: 101 HCO3 Arterial: 18.3 BEb Arterial: -5.9 A-aDO2 Arterial: -3.00 sO2 Arterial: 99 Na+ Arterial: 136 K+ Arterial: 4.5 Cl - Arterial: 111 Ca2+ Arterial: 1.17 Glucosa Arterial: 111 Hemoglobina Art: 11.6 (g/dl) Hematocrito Art: 35.0 Oxihemoglobina Art: 98 Hemoglobina Reducida Art: 1 Carboxihemoglobina Art: 2 Metahemoglobina Art: 0 Anion GAP Arterial: 11.0 Lactato Arterial: 0.90 FIO2: 21.0 P/F Ratio Arterial: 481 pAO2 Arterial: 98 CaO2 Arterial: 16.0 RI Arterial: 0.0 pO2/FiO2: 481 Comentario Gasometria:: Gasometria compatible con una Acidosis metabolica compensada.Valorar trastorno mixto cuando la respuesta compensadora sea mayor o menor de lo esperado.',
#  'Fecha: 01jun2021 DIAGNÓSTICOS Y PROCEDIMIENTOS: EICH agudo tipo NET tras tx hepático con afectación cutanea, medular y GI Hipocalcemia, hipomagensemia, hipofosofremia y ehipopotasemia e hiponatremia 2º a eEICH y luego a foscarnet Enfermedad por Citomegalovirus Trasplante hepático por Cirrosis hepática secundaria overlap HAI/CEP Enteritis regional LES CON AFECTACION CUTANEA Y HEMATOLOGICA en tratamiento con esteroides y azatiorpina. Infección genirtal por Herpes tipo 2 OBSERVACIONES: Antecedentes Familiares: . Antecedentes Personales: -Somaticos: no alergias medicamentosas conocidas. DLP. LES con afectacion articular, dermatologica y hematologica. Enfermedad de Crohn. TBC latente tratada. Gamapatia monoclonal. Anemia ferropenica. Vasculitis leucocitoclastica. Gastritis Cronica. Ulceras perianales secundarias a herpes virus tipo 2 resueltas. Enfermedad de Chagas en fase cronica indeterminada. Osteopenia multifactorial. Insuficiencia mitral leve. Pancitopenia por hiperesplenismo. Colangitis de repeticion. IQ: conizacion cervical en 2016, transplante hepatico en 2019 por cirrosis hepatica en contexto de hepatitis autoinmune, incluyendo debut de enfermedad de injerto contra huesped (EICH). -Psiquiatricos: diagnosticada de trastorno adaptativo, describiendose en informes clinica depresiva desde 2013 tras el fallecimiento de la madre. Realizo seguimiento en CSM Usera en 2015-2016, siendo dada de alta. Valorada en julio de 2019 a traves de nuestro servicio de interconsulta hospitalaria de Psiquiatria durante ingreso a cargo de Cirugia General y Digestiva. No ingresos psiquiatricos previos. Tratamiento en el pasado con Paroxetina y Escitalopram, refiriendo buen efecto clinico de ambos. -Antecedentes familiares psiquiatricos: niega. -Situacion socio-familiar: natural de Bolivia, en Espana desde 2005. Divorciada, 2 hijos y otro en acogida, la segunda de 5 hermanos (la tercera fallecida, el mayor en paradero desconocido), padres fallecidos. Convive con una amiga. Actualmente de baja laboral temporal, pendiente de valorar incapacidad laboral permanente. -Habitos toxicos: niega. Tratamiento: Dolquine, Prednisona, Claversal, Advagraf, Aciclovir, Famotidina, Calcio carbonato, Hidroxicloroquina, Eritropoyetina semanal. Antecedentes obstetrico quirurgicos: . Antecedentes profesionales: . Situacion social Convivencia: . Motivo de alta formulario: -1 Dieta texto libre: DIETA SIN LACTOSA Fecha de llegada a Espana: . Fecha ultimo viaje a pais origen: . Indicaciones al Alta: - La paciente debe continuar en tratamiento profliactico para el Pn. Jirovecci con Dapsona de forma indefenida. - Pido espirometria y rxtx y citar en consulta con el resultado Intolerancia: . Motivo de Ingreso: Seguimiento Orientacion Diagnostica: RXTX 25/5/2021: Disponemos del estudio previo realizado el 05/04/2021 para poder comparar. No se identifican cambios significativos. Dermatologia Abril 21: melasma vs melanosis de Rihel Pais de origen: . Prescripcion al alta: - DAPSONA 100 MG 1 COMPRIMIDO al dia - EPO alfa 10.000 cada 15 dias - Resto del tratamiento como venia haciendo. Problema Actual: Paciente de 51 anos con: 1. Trasplante hepatico el 17/4/2019 en pcte con LES y EII por hepatitis autoinmune overlacp CEP , en tto con tacrolimus y azatioprina. Al ingreso por la sospecha de SSJ en relacion con tacrolimus se cambia a MMF y everolim ... Pruebas complementarias Lab: Quimerismo Quimerismo del receptor en celularidad total : 3.60% el 8/7/19, 14.3% el 8/8/19, 28/8/19 12%, 18/10/19 3.7%., 17/10/2020: 3.71 %, Diciembre 2019: 10.44 %, 21/2 8,24% el, Marzo 2020 8,4%. Mayo 2020: 2.23% Analitica 5/12/2020 Ac. Anti Nucleares-Screening MultiPlex Comentario (R) Existe un resultado previo de Ac. Anti Nucleares-Screening MultiPlex con valor "Positivo" el dia 21/05/2019. , Ac. Anti RNP * , Ac. Anti RNP-A * , Ac. Anti cardiolipina IgG 5.70 (U/ml) CT, Ac. Anti Cardiolipina IgM 12.40 (U/ml) UFL/m, Ac. Anti B2 GPI IgA 2.7 (U/ml) UFL/ml, Ac. Anti B2 GPI - IgG 5.1 (U/ml) UFL/ml, Ac. Anti B2  ...
#  'Fecha: 02jun2021 OBSERVACIONES: Ecografia Abdominal: \\\\HDOC\\ARCHIVOS\\INFORMES\\\\2021\\06\\02\\ECO_EII2017050106.pdf I_ECO_EII: \\\\HDOC\\ARCHIVOS\\INFORMES\\\\2021\\06\\02\\I_ECO_EII_1_2017050106.jpg I_ECO_EII: \\\\HDOC\\ARCHIVOS\\INFORMES\\\\2021\\06\\02\\I_ECO_EII_2_2017050106.jpg I_ECO_EII: \\\\HDOC\\ARCHIVOS\\INFORMES\\\\2021\\06\\02\\I_ECO_EII_3_2017050106.jpg I_ECO_EII: \\\\HDOC\\ARCHIVOS\\INFORMES\\\\2021\\06\\02\\I_ECO_EII_4_2017050106.jpg I_ECO_EII: \\\\HDOC\\ARCHIVOS\\INFORMES\\\\2021\\06\\02\\I_ECO_EII_5_2017050106.jpg I_ECO_EII: \\\\HDOC\\ARCHIVOS\\INFORMES\\\\2021\\06\\02\\I_ECO_EII_6_2017050106.jpg I_ECO_EII: \\\\HDOC\\ARCHIVOS\\INFORMES\\\\2021\\06\\02\\I_ECO_EII_7_2017050106.jpg Antecedentes Familiares: . Antecedentes Personales: -Somaticos: no alergias medicamentosas conocidas. DLP. LES con afectacion articular, dermatologica y hematologica. Enfermedad de Crohn. TBC latente tratada. Gamapatia monoclonal. Anemia ferropenica. Vasculitis leucocitoclastica. Gastritis Cronica. Ulceras perianales secundarias a herpes virus tipo 2 resueltas. Enfermedad de Chagas en fase cronica indeterminada. Osteopenia multifactorial. Insuficiencia mitral leve. Pancitopenia por hiperesplenismo. Colangitis de repeticion. IQ: conizacion cervical en 2016, transplante hepatico en 2019 por cirrosis hepatica en contexto de hepatitis autoinmune, incluyendo debut de enfermedad de injerto contra huesped (EICH). -Psiquiatricos: diagnosticada de trastorno adaptativo, describiendose en informes clinica depresiva desde 2013 tras el fallecimiento de la madre. Realizo seguimiento en CSM Usera en 2015-2016, siendo dada de alta. Valorada en julio de 2019 a traves de nuestro servicio de interconsulta hospitalaria de Psiquiatria durante ingreso a cargo de Cirugia General y Digestiva. No ingresos psiquiatricos previos. Tratamiento en el pasado con Paroxetina y Escitalopram, refiriendo buen efecto clinico de ambos. -Antecedentes familiares psiquiatricos: niega. -Situacion socio-familiar: natural de Bolivia, en Espana desde 2005. Divorciada, 2 hijos y otro en acogida, la segunda de 5 hermanos (la tercera fallecida, el mayor en paradero desconocido), padres fallecidos. Convive con una amiga. Actualmente de baja laboral temporal, pendiente de valorar incapacidad laboral permanente. -Habitos toxicos: niega. Tratamiento: Dolquine, Prednisona, Claversal, Advagraf, Aciclovir, Famotidina, Calcio carbonato, Hidroxicloroquina, Eritropoyetina semanal. Antecedentes obstetrico quirurgicos: . Antecedentes profesionales: . Situacion social Convivencia: . Motivo de alta formulario: -1 Dieta texto libre: DIETA SIN LACTOSA Fecha de llegada a Espana: . Fecha ultimo viaje a pais origen: . Indicaciones al Alta: - La paciente debe continuar en tratamiento profliactico para el Pn. Jirovecci con Dapsona de forma indefenida. - Pido espirometria y rxtx y citar en consulta con el resultado Intolerancia: . Motivo de Ingreso: Seguimiento Orientacion Diagnostica: M. Interna consulta 2/6/2021. Dra Ga Reyne 68990 La paciente se encuentra bien clinicamente. Sigue con el dolor abdominal cronico por el que se ha hecho hoy una eco y que le esta viendo Digestivo. La tos ha mejorado. No refiere disnea. PC\\ ... Pais de origen: . Prescripcion al alta: - DAPSONA 100 MG 1 COMPRIMIDO al dia - EPO alfa 10.000 cada 15 dias - Resto del tratamiento como venia haciendo. Problema Actual: Paciente de 51 anos con: 1. Trasplante hepatico el 17/4/2019 en pcte con LES y EII por hepatitis autoinmune overlacp CEP , en tto con tacrolimus y azatioprina. Al ingreso por la sospecha de SSJ en relacion con tacrolimus se cambia a MMF y everolim ... Pruebas complementarias Lab: Quimerismo Quimerismo del receptor en celularidad total : 3.60% el 8/7/19, 14.3% el 8/8/19, 28/8/19 12%, 18/10/19 3.7%., 17/10/2020: 3.71 %, Diciembre 2019: 10.44 %, 21/2 8,24% el, Marzo 2020 8,4%. Mayo 2020: 2.23% Analitica 5/12/2020 Ac. Anti Nucleares-Screening MultiPlex Comentario (R) Existe un resultado previo de Ac. Anti Nucleare ...
#  'Fecha: 18jun2021 OBSERVACIONES: Evolucion Datos Laboratorio: 213332508 Tiempo de Protrombina: 12.1 Actividad de Protrombina: 92 INR (Laboratorio): 1.05 TTPa: 31 Fibrinogeno (Derivado): 335 Indice de Hemolisis: 7 Indice de Lipemia: 2 Indice de Ictericia13: 1 Glucosa: 91 Creatinina: 1.14 Filtrado Glomerular (ckd-epi): 55 Sodio: 140 Proteinas Totales: 7.0 Potasio: 4.59 Albumina: 4.8 Cloro: 109 Calcio: 9.6 ALT (GPT): 21 AST (GOT): 23 Gamma-GT: 50 Fosfatasa Alcalina: 81 Bilirrubina: 0.4 Colesterol: 181 Trigliceridos: 59 LDL (estimacion Friedewald): 99 HDL: 70 Colesterol-No HDL: 111.2 Relacion LDL/HDL: 1.42 Relacion Colesterol/HDL: 2.59 Proteina C Reactiva: 0.60 Ferritina: 77 Hierro: 71 Transferrina: 227 TIBC: 320 % Saturacion Transferrina: 22.3 Hematies: 4.48 Hemoglobina: 13.8 Hematocrito: 42.2 HCM: 30.9 VCM: 94.3 CHCM: 32.8 RDW: 14.3 Plaquetas: 96 VPM: 10.4 Leucocitos: 3.4 Neutrofilos: 1.9 Neutrofilos %: 54.7 Linfocitos: 1.2 Linfocitos %: 35.9 Monocitos: 0.2 Monocitos %: 7.4 Eosinofilos: 0.1 Eosinofilos %: 1.6 Basofilos: 0.0 Basofilos %: 0.4 MORFOLOGIA DE SP:: * Vitamina B12: 495.90 Acido Folico: 7.1 Evolucion Datos Laboratorio: 213332511 Calprotectina Fecal: 103 (?g/gheces) Vitamina D (25-OH-Vitamina D): 18.7 Resultado:: Negativo Prueba:: ^ TOXINA CLOSTRIDIUM DIFFICILE Muestra:: HECES Resultado:: Negativo Prueba:: ^ CRYPTOSPORIDIUM ANTIGENO Muestra:: HECES Resultado:: Negativo Prueba:: ^ GIARDIA LAMBLIA ANTIGENO Muestra:: HECES',
#  'Fecha: 29jun2021 ANOTACIONES: 28 de junio de 2021: era telefonica pero ha venido presencial. Claversal 3 g al dia, famotidina 40 mg 1-0-1, Advagraf 5 mg/dia, Dapsona un comprimido la dia, prednisona 5 mg/d por la manana, Deltius mensual, calcio, azatioprina 25 mg /dia, EPO cada 15 dias. ha desaparecido el dolor en FID que correspondia a la zona visible en la eco con actividad inflamatoria. Sin embargo le molestia algo el estomago y tiene mal estar y plenitud que relaciona con as dosis mas altas de mesalazina. No nauseas, vomitos ni sangrado ni fiebre. Hoy consulta en Tx hepatico. exploracion: AS: trombopenia y leucopenia. CF 103 (muy levemente aumentado) JC: los mismos. mejoria clara de la clinica de colitis derecha. Puede cierta intolerancia gastrica a las dosis mas altas de mesalazina Plan. 1.- Bajamos a 2 g de Claversal y control ecografico. 28 de junio de 2021: era telefonica pero ha venido presencial. Claversal 3 g al dia, famotidina 40 mg 1-0-1, Advagraf 5 mg/dia, Dapsona un comprimido la dia, prednisona 5 mg/d por la manana, Deltius mensual, calcio, azatioprina 25 mg /dia, EPO cada 15 dias. ha desaparecido el dolor en FID que correspondia a la zona visible en la eco con actividad inflamatoria. Sin embargo le molestia algo el estomago y tiene mal estar y plenitud que relaciona con as dosis mas altas de mesalazina. No nauseas, vomitos ni sangrado ni fiebre. Hoy consulta en Tx hepatico. exploracion: normal AS: trombopenia y leucopenia. CF 103 (muy levemente aumentado) JC: los mismos. mejoria clara de la clinica de colitis derecha. Puede cierta intolerancia gastrica a las dosis mas altas de mesalazina Plan. 1.- Bajamos a 2 g de Claversal y control ecografico en agosto. 2.- Cita en septiembre. Se hace control de medicacion. La paciente se encuentra bien, sin incidencias desde la anterior visita. Analitica normal, cita en 5 meses. Se da volante de analitica para siguiente consulta DIAGNÓSTICOS Y PROCEDIMIENTOS: Enteritis regional Adenomas tubulares de bajo grado y pólipo hiperplásico extripados en colonoscopia 2015 Ci hepatica (overlap HAI+CEP). Tx hepatico el 18 de abril de 2019. GHVD controlado actualmente LES CON AFECTACION CUTANEA Y HEMATOLOGICA actualmente controlado Infeccion por COVID-19 en septiembre de 2020 Adenoma tubular d ebajo grado eb colonoscopia + cromoendoscopia de 2020 Enfermedad por Citomegalovirus (2019) Enfermedad por CMV diseminado con afectacion del colon y panctopenia (2019) Colits derecha leve en junio 2021 con mejoria clinica la aumentar mesalalina dispespia con compeente de RGe sin datos de alarrma resuelto con antiH2. leucopenia por IBP OBSERVACIONES: Antecedentes Familiares: . Antecedentes Personales: -Somaticos: no alergias medicamentosas conocidas. DLP. LES con afectacion articular, dermatologica y hematologica. Enfermedad de Crohn. TBC latente tratada. Gamapatia monoclonal. Anemia ferropenica. Vasculitis leucocitoclastica. Gastritis Cronica. Ulceras perianales secundarias a herpes virus tipo 2 resueltas. Enfermedad de Chagas en fase cronica indeterminada. Osteopenia multifactorial. Insuficiencia mitral leve. Pancitopenia por hiperesplenismo. Colangitis de repeticion. IQ: conizacion cervical en 2016, transplante hepatico en 2019 por cirrosis hepatica en contexto de hepatitis autoinmune, incluyendo debut de enfermedad de injerto contra huesped (EICH). -Psiquiatricos: diagnosticada de trastorno adaptativo, describiendose en informes clinica depresiva desde 2013 tras el fallecimiento de la madre. Realizo seguimiento en CSM Usera en 2015-2016, siendo dada de alta. Valorada en julio de 2019 a traves de nuestro servicio de interconsulta hospitalaria de Psiquiatria durante ingreso a cargo de Cirugia General y Digestiva. No ingresos psiquiatricos previos. Tratamiento en el pasado con Paroxetina y Escitalopram, refiriendo buen efecto clinico de ambos. -Antecedentes familiares psiquiatricos: niega. -Situacion socio-familiar: natural de Bolivia, en Espana desde 2005. Divorciada, 2 hijos y otro en acogida ...
#  'Fecha: 19jul2021 ANOTACIONES: Paciente con Lupus y tx hepatico que acude a consulta derivada de odontolog para valorar exodonica de pieza 18. EN tratamiento con biologicos y ac. zolendronico (anual), ultima dosis en noviembre del 2020. REfiere que el odpntologo le recomienda exo de 18 por caries y le ha planteado poner implantes. EF: Pieza 18 sin movilidad, no aprecio caries. No fistula, no colecciones palpables. PLAN: - Planteo tratamiento conservador con odontologo de pieza 18, obturacion, endodoncia. - Cita en septiembre con OPG e informe de dentista. - Desaconsejo realizacion de implantes. OBSERVACIONES: Antecedentes Familiares: . Antecedentes Personales: -Somaticos: no alergias medicamentosas conocidas. DLP. LES con afectacion articular, dermatologica y hematologica. Enfermedad de Crohn. TBC latente tratada. Gamapatia monoclonal. Anemia ferropenica. Vasculitis leucocitoclastica. Gastritis Cronica. Ulceras perianales secundarias a herpes virus tipo 2 resueltas. Enfermedad de Chagas en fase cronica indeterminada. Osteopenia multifactorial. Insuficiencia mitral leve. Pancitopenia por hiperesplenismo. Colangitis de repeticion. IQ: conizacion cervical en 2016, transplante hepatico en 2019 por cirrosis hepatica en contexto de hepatitis autoinmune, incluyendo debut de enfermedad de injerto contra huesped (EICH). -Psiquiatricos: diagnosticada de trastorno adaptativo, describiendose en informes clinica depresiva desde 2013 tras el fallecimiento de la madre. Realizo seguimiento en CSM Usera en 2015-2016, siendo dada de alta. Valorada en julio de 2019 a traves de nuestro servicio de interconsulta hospitalaria de Psiquiatria durante ingreso a cargo de Cirugia General y Digestiva. No ingresos psiquiatricos previos. Tratamiento en el pasado con Paroxetina y Escitalopram, refiriendo buen efecto clinico de ambos. -Antecedentes familiares psiquiatricos: niega. -Situacion socio-familiar: natural de Bolivia, en Espana desde 2005. Divorciada, 2 hijos y otro en acogida, la segunda de 5 hermanos (la tercera fallecida, el mayor en paradero desconocido), padres fallecidos. Convive con una amiga. Actualmente de baja laboral temporal, pendiente de valorar incapacidad laboral permanente. -Habitos toxicos: niega. Tratamiento: Dolquine, Prednisona, Claversal, Advagraf, Aciclovir, Famotidina, Calcio carbonato, Hidroxicloroquina, Eritropoyetina semanal. Antecedentes obstetrico quirurgicos: . Antecedentes profesionales: . Situacion social Convivencia: . Motivo de alta formulario: -1 Fecha de llegada a Espana: . Fecha ultimo viaje a pais origen: . Intolerancia: . Pais de origen: . RAZA_EST: Hispana Situacion fisica: . Situacion mental: . Antecedentes Personales: -Somaticos: no alergias medicamentosas conocidas. DLP. LES con afectacion articular, dermatologica y hematologica. Enfermedad de Crohn. TBC latente tratada. Gamapatia monoclonal. Anemia ferropenica. Vasculitis leucocitoclastica. Gastritis Cronica. Ulceras perianales secundarias a herpes virus tipo 2 resueltas. Enfermedad de Chagas en fase cronica indeterminada. Osteopenia multifactorial. Insuficiencia mitral leve. Pancitopenia por hiperesplenismo. Colangitis de repeticion. IQ: conizacion cervical en 2016, transplante hepatico en 2019 por cirrosis hepatica en contexto de hepatitis autoinmune, incluyendo debut de enfermedad de injerto contra huesped (EICH). -Psiquiatricos: diagnosticada de trastorno adaptativo, describiendose en informes clinica depresiva desde 2013 tras el fallecimiento de la madre. Realizo seguimiento en CSM Usera en 2015-2016, siendo dada de alta. Valorada en julio de 2019 a traves de nuestro servicio de interconsulta hospitalaria de Psiquiatria durante ingreso a cargo de Cirugia General y Digestiva. No ingresos psiquiatricos previos. Tratamiento en el pasado con Paroxetina y Escitalopram, refiriendo buen efecto clinico de ambos. -Antecedentes familiares psiquiatricos: niega. -Situacion socio-familiar: natural de Bolivia, en Espana desde 2005. Divorciada, 2 hijos y otro en aco ...
# ...
#  'Fecha: 13mar2022 ANOTACIONES: OFTALMOLOGÍA URGENCIASHistoria actualOjo derecho: dolor y ojo rojo desde ayer, sin aumento de secreciones.APoft: miopía y astigmatismo.AP: traspalnte hígado. No está anticoagulada. No HTA. Refiere que antes tomaba amlodipino pero se lo retiraron.ExploraciónTensión sistólica(mm Hg):151, Tensión diastólica(mm Hg):90, Frecuencia Cardíaca(lat/min):74.BMC OD: hiposfagma temporal con quemosis, córnea transparente con queratitis punteada superficial fluo + central, pterigium nasal, BCA, no tyndall, fáquica.PINRs. MOES conservados no dolorosos.Juicio clínicoHiposfagma ODQueratitis ODPlanLagrimas artificiales (Aquoral) 4-6 veces al día mientras tenga molestias.Xilin night cada 12 horas mientras esté el ojo inflamado.Control de tensión arterial por médico de atención primaria. DIAGNÓSTICOS Y PROCEDIMIENTOS: Hemorragia subconjuntival (hiposfagma) OBSERVACIONES: Comentarios enfermeria: Molestia OD Motivo de consulta: Problemas oculares Discriminador: Dolor Dolor Reposo: 2 Saturacion O2 Tension sistolica: 151 Tension diastolica: 90 Tension Arterial Media: 108 Frecuencia Cardiaca: 74 TAS sentado: 151 (mmHg) TAD sentado: 90 (mmHg) Pulso: 74 (pul/min) Antecedentes Personales: Paciente de 50 anos con AP de - LES con afectacion cutanea, articular y hematologica. En tratamiento con prednisoa y aztioprina con buen control con algun borte articular de las manos leve. En seguimiento pot Reumatologia, ultima revision e ... Antecedentes profesionales: . Fecha de llegada a Espana: . Situacion fisica: . Pais de origen: . Motivo de alta formulario: -1 Antecedentes obstetrico quirurgicos: . Intolerancia: . Fecha ultimo viaje a pais origen: . RAZA_EST: Hispana Antecedentes Familiares: . Motivo de Ingreso: Dolor ojo derecho Situacion mental: . Situacion social Convivencia: . Antecedentes Personales: Paciente de 50 anos con AP de - LES con afectacion cutanea, articular y hematologica. En tratamiento con prednisoa y aztioprina con buen control con algun borte articular de las manos leve. En seguimiento pot Reumatologia, ultima revision en ... Antecedentes profesionales: . Fecha de llegada a Espana: . Fecha de alta formulario: 13/03/2022 Situacion fisica: . Pais de origen: . Motivo de alta formulario: 1 Antecedentes obstetrico quirurgicos: . Hora de alta formulario: 14:29 Intolerancia: . Fecha ultimo viaje a pais origen: . RAZA_EST: Hispana Antecedentes Familiares: . Motivo de Ingreso: Dolor ojo derecho Situacion mental: . Situacion social Convivencia: .',
#  'Fecha: 28mar2022 ANOTACIONES: REHABILITACIONRevisionNO esta nformada RMNRefiere dos onconticencia urinaria nocturnaEF: Apofisalgias difusas C6, T12, NO dolor angular de escapulas ni trapecios.No dolor hombrosRotulianos vivosPLan: pendiente resultados RMN OBSERVACIONES: Antecedentes obstetrico quirurgicos: . Antecedentes profesionales: . Orden Medica: 3 Situacion mental: . Antecedentes Personales: Paciente de 50 anos con AP de - LES con afectacion cutanea, articular y hematologica. En tratamiento con prednisoa y aztioprina con buen control con algun borte articular de las manos leve. En seguimiento pot Reumatologia, ultima revision en ... Antecedentes Familiares: . Situacion social Convivencia: . Intolerancia: . Pais de origen: . Motivo de alta formulario: -1 Fecha ultimo viaje a pais origen: . Situacion fisica: . RAZA_EST: Hispana Fecha de llegada a Espana: .',
#  'Fecha: 04apr2022 ANOTACIONES: REHABILITACIONRevidionPaciente pluripatológica: LES, tx hepático, osteoporosis. dorsalgia muscular. Revision con RMN cervical y dorsal.RMN: 1. Cambios incipientes de espondilosis degenerativa en C4-C5. Pequeño nódulo de Schmörl en platillo vertebral superior de C7. Abombamientos discales difusos en estos dos niveles, con mínima impronta sobre convexidad anterior de médula cervical. No hay estenosis de canal central ni foraminal significativa en estos niveles.2. Estabilidad de leve deformidad en cuña de D11 con presencia de nódulo de Schmörl. NO hay edema óseo. NO hay compromiso de canal.Dx OP en ttoRevision con PPCCLa pacietne refeire dolor cervical que le despierta por la nocheEl dolor no se irradia por MMSS ni II. Refiere sensacion de calambres que le obligan a paralizarse en bipedestacion.Realzia tto Bifosofnato anual en seguimineto su OP en reumatologia.EF: Apofisalgias difusas C6, T12, NO dolor angular de escapulas ni trapecios.No dolor hombrosJC: Cervico-dorsalgia. Fx antigua en cuña de D11 Plan: TTo en sala encaminado a realziar ej que posteriormente realzar en domicilio DIAGNÓSTICOS Y PROCEDIMIENTOS: Cervico-dorsalgia. Fx antigua en cuña de D11 Cervico-dorsalgia. Fx antigua en cuña de D11 OBSERVACIONES: INFORME DE RM DE COLUMNA CERVICAL: \\\\HDOC\\ARCHIVOS\\INFORMES\\2022\\03\\19\\RIS_8949261.pdf INFORME DE RM DE COLUMNA DORSAL: \\\\HDOC\\ARCHIVOS\\INFORMES\\2022\\03\\19\\RIS_8949264.pdf Antecedentes Familiares: . Antecedentes Personales: Paciente de 50 anos con AP de - LES con afectacion cutanea, articular y hematologica. En tratamiento con prednisoa y aztioprina con buen control con algun borte articular de las manos leve. En seguimiento pot Reumatologia, ultima revision en ... Antecedentes obstetrico quirurgicos: . Antecedentes profesionales: . Situacion social Convivencia: . Motivo de alta formulario: -1 Fecha de llegada a Espana: . Fecha ultimo viaje a pais origen: . Intolerancia: . Pais de origen: . RAZA_EST: Hispana Situacion fisica: . Situacion mental: . Antecedentes Familiares: . Antecedentes Personales: Paciente de 50 anos con AP de - LES con afectacion cutanea, articular y hematologica. En tratamiento con prednisoa y aztioprina con buen control con algun borte articular de las manos leve. En seguimiento pot Reumatologia, ultima revision en ... Antecedentes obstetrico quirurgicos: . Antecedentes profesionales: . Situacion social Convivencia: . Motivo de alta formulario: -1 Fecha de llegada a Espana: . Fecha ultimo viaje a pais origen: . Intolerancia: . Motivo de Ingreso: Cervico-dorsalgia. Fx. antigua en cuna de D11 Pais de origen: . RAZA_EST: Hispana Situacion fisica: . Situacion mental: . Orden Medica: 1',
#  'Fecha: 19apr2022 ANOTACIONES: Visto TC , se envia por correo OBSERVACIONES: Intolerancia: . Antecedentes Familiares: . Antecedentes Personales: Paciente de 50 anos con AP de - LES con afectacion cutanea, articular y hematologica. En tratamiento con prednisoa y aztioprina con buen control con algun borte articular de las manos leve. En seguimiento pot Reumatologia, ultima revision en ... Antecedentes obstetrico quirurgicos: . Situacion social Convivencia: . Antecedentes profesionales: . RAZA_EST: Hispana Pais de origen: . Fecha de llegada a Espana: . Fecha ultimo viaje a pais origen: .',
#  'Fecha: 18may2022 ANOTACIONES: Se reclama radografía de tórax. Los celadores me informan de que la han llamado en varias ocasiones para realizar la radiografía pero no contesta. Llamo a información y contactan con la paciente que se encuentra en el hospital. Le indico que acuda a la sala de espera de ambulantes OBSERVACIONES: Saturacion O2: 93 Frecuencia Cardiaca: 75 Tension sistolica: 121 Tension diastolica: 64 Tension Arterial Media: 80 Temperatura: 36.7 Saturacion O2: 93 Pulso: 75 (pul/min) TAS sentado: 121 (mmHg) TAD sentado: 64 (mmHg) Temperatura: 36.7 Comentarios enfermeria: Derivadapor MAP por dolor toracico + disnea en paciente con alto riesgo CV. Alt en EKG. Motivo de consulta: Dolor toracico Discriminador: Dolor cardiaco Saturacion O2: 95 Frecuencia Cardiaca: 85 Saturacion O2: 95 Pulso: 85 (pul/min) Antecedentes Familiares: . Antecedentes Personales: Paciente de 50 anos con AP de - LES con afectacion cutanea, articular y hematologica. En tratamiento con prednisoa y aztioprina con buen control con algun borte articular de las manos leve. En seguimiento pot Reumatologia, ultima revision en ... Antecedentes obstetrico quirurgicos: . Antecedentes profesionales: . Situacion social Convivencia: . Motivo de alta formulario: -1 Fecha de llegada a Espana: . Fecha ultimo viaje a pais origen: . Intolerancia: . Medicacion previa HDO: (pendiente de actualizar)- TACROLIMUS 5 MG 1-0-0 - FAMOTIDINA 40 MG /12 HORAS - DAPSONA 100 MG 1 COMPRIMIDO al da - PREDNISONA 5 MG COMPRIMIDO: 1 comprimido CADA 24 HORAS (9:00) ... Pais de origen: . RAZA_EST: Hispana Situacion fisica: . Situacion mental: . ELECTROCARDIOGRAMA: \\\\HDOC\\ARCHIVOS\\INFORMES\\2022\\05\\18\\CECG2093548338.pdf Eje complejo QRS: 71 Eje onda T: 72 Eje onda P: 65 Duracion QRS: 88 Intervalo PR: 155 Frecuencia Cardiaca del ECG: 69 Intervalo QT Corregido QTc (Bazett): 423 Intervalo QT: 395 Ver ECG: \\\\HDOC\\ARCHIVOS\\INFORMES\\2022\\05\\18\\CECG2093548338.pdf Antecedentes Familiares: . Antecedentes Personales: Paciente de 50 anos con AP de - LES con afectacion cutanea, articular y hematologica. En tratamiento con prednisoa y aztioprina con buen control con algun borte articular de las manos leve. En seguimiento pot Reumatologia, ultima revision en ... Antecedentes obstetrico quirurgicos: . Antecedentes profesionales: . Situacion social Convivencia: . Motivo de alta formulario: -1 Fecha de llegada a Espana: . Fecha ultimo viaje a pais origen: . Intolerancia: . Medicacion previa HDO: (pendiente de actualizar)- TACROLIMUS 5 MG 1-0-0 - FAMOTIDINA 40 MG /12 HORAS - DAPSONA 100 MG 1 COMPRIMIDO al dia - PREDNISONA 5 MG COMPRIMIDO: 1 comprimido CADA 24 HORAS (9:00) por via ... Pais de origen: . Problema Actual: Paciente con los antecedentes descritos que acude por presentar episodios de opresin centrotorcica y disnea con el esfuerzo de dos semanas de evolucin, tras episodio de atragantamiento en domicilio. Niega fie ... RAZA_EST: Hispana Situacion fisica: . Situacion mental: . Exploracion: Sat basal 94%.Consciente, orientada. Eupneica en reposo. Palidez.AC: Rtmica, sin soplos. AP: MVC sin ruidos aadidos.Abd: Cicatriz (Tx hepatico). Blando, no doloroso. Sin signos de irr ... Antecedentes Familiares: . Antecedentes Personales: Paciente de 50 anos con AP de - LES con afectacion cutanea, articular y hematologica. En tratamiento con prednisoa y aztioprina con buen control con algun borte articular de las manos leve. En seguimiento pot Reumatologia, ultima revision en ... Antecedentes obstetrico quirurgicos: . Antecedentes profesionales: . Situacion social Convivencia: . Motivo de alta formulario: -1 Exploracion: Sat basal 94%.Consciente, orientada. Eupneica en reposo. Palidez.AC: Rtmica, sin soplos. AP: MVC sin ruidos aadidos.Abd: Cicatriz (Tx hepatico). Blando, no doloroso. Sin signos de irr ... Fecha de llegada a Espana: . Fecha ultimo viaje a pais origen: . Intolerancia: . Medicacion previa HDO: (pendiente de actualizar)- TACROLIMUS 5 MG 1-0-0 - FAMOTIDINA 40 MG /12 HORAS - DAPSONA 10 ...
#  'Fecha: 19may2022 PRESCRIPCIÓN NO FARMACOLÓGIC: Monitorizacion continua, Continuamente Constantes por turno, POR TURNO Dieta absoluta, POR TURNO Dieta normal, POR TURNO Monitorizacion continua, Continuamente Dieta normal, POR TURNO Constantes por turno, POR TURNO PRESCRIPCIÓN FARMACOLÓGICA: (ADVAgraf) tacrolimus 5 mg capsula liberacion modificada Cantidad de dosis: 1, Unidad de dosis: CAPS, Cantidad de principio activo principal: 5, Unidad de principio activo principal: MG, Vía de administración: B21, Fecha de inicio de la medicación: 2022-05-19, Fecha de fin de la medicación: 2022-05-19, famotidina 20 mg comprimido Cantidad de dosis: 1, Unidad de dosis: COMP, Cantidad de principio activo principal: 20, Unidad de principio activo principal: MG, Vía de administración: B21, Fecha de inicio de la medicación: 2022-05-19, Fecha de fin de la medicación: 2022-05-19, prednisona 5 mg comprimido Cantidad de dosis: 1, Unidad de dosis: COMP, Cantidad de principio activo principal: 5, Unidad de principio activo principal: MG, Vía de administración: B21, Fecha de inicio de la medicación: 2022-05-19, Fecha de fin de la medicación: 2022-05-19, calcio carbonato/colecalciferol 1.500 mg (600 mg ca)/1.000 ui comprimido bucodispersable/liotab Cantidad de dosis: 1, Unidad de dosis: COMP, Cantidad de principio activo principal: 1500, Unidad de principio activo principal: MG, Vía de administración: B21, Fecha de inicio de la medicación: 2022-05-19, Fecha de fin de la medicación: 2022-05-19, hidroxicloroquina 200 mg comprimido Cantidad de dosis: 0.5, Unidad de dosis: COMP, Cantidad de principio activo principal: 100, Unidad de principio activo principal: MG, Vía de administración: B21, Fecha de inicio de la medicación: 2022-05-19, Fecha de fin de la medicación: 2022-05-19, mesalazina 500 mg comprimido Cantidad de dosis: 1, Unidad de dosis: COMP, Cantidad de principio activo principal: 500, Unidad de principio activo principal: MG, Vía de administración: B21, Fecha de inicio de la medicación: 2022-05-19, Fecha de fin de la medicación: 2022-05-19, aciclovir 200 mg comprimido Cantidad de dosis: 1, Unidad de dosis: COMP, Cantidad de principio activo principal: 200, Unidad de principio activo principal: MG, Vía de administración: B21, Fecha de inicio de la medicación: 2022-05-19, Fecha de fin de la medicación: 2022-05-19, acido acetilSALICILICO 300 mg comprimidos Cantidad de dosis: 1, Unidad de dosis: COMP, Cantidad de principio activo principal: 300, Unidad de principio activo principal: MG, Vía de administración: B21, Fecha de inicio de la medicación: 2022-05-19, Fecha de fin de la medicación: 2022-05-19, acido acetilSALICILICO 100 mg comprimidos Cantidad de dosis: 1, Unidad de dosis: COMP, Cantidad de principio activo principal: 100, Unidad de principio activo principal: MG, Vía de administración: B21, Fecha de inicio de la medicación: 2022-05-20, Fecha de fin de la medicación: 2022-05-20, famotidina 20 mg comprimido Cantidad de dosis: 1, Unidad de dosis: COMP, Cantidad de principio activo principal: 20, Unidad de principio activo principal: MG, Vía de administración: B21, Fecha de inicio de la medicación: 2022-05-19, Fecha de fin de la medicación: 2022-05-21, mesalazina 500 mg comprimido Cantidad de dosis: 1, Unidad de dosis: COMP, Cantidad de principio activo principal: 500, Unidad de principio activo principal: MG, Vía de administración: B21, Fecha de inicio de la medicación: 2022-05-19, Fecha de fin de la medicación: 2022-05-21, acido acetilSALICILICO 100 mg comprimidos Cantidad de dosis: 1, Unidad de dosis: COMP, Cantidad de principio activo principal: 100, Unidad de principio activo principal: MG, Vía de administración: B21, Fecha de inicio de la medicación: 2022-05-20, Fecha de fin de la medicación: 2022-05-21, hidroxicloroquina 200 mg comprimido Cantidad de dosis: 0.5, Unidad de dosis: COMP, Cantidad de principio activo principal: 100, Unidad de principio activo principal: MG, Vía de administración: B21, Fecha de inicio de la medicación: 2022-0 ...

# %%
df['visits_num'] = df['visits'].apply(len)

# %%
df
# Out:
#               person_id  label  \
# 0    PATTERN_M-00314259      1
# 1    PATTERN_M-00337378      1
# 2    PATTERN_M-00710666      1
# 3    PATTERN_M-01649881      2
# 4    PATTERN_M-01756648      1
# ..                  ...    ...
# 163  PATTERN_M-03510507      0
# 164  PATTERN_M-02301744      0
# 165  PATTERN_M-02021706      0
# 166  PATTERN_M-03657032      0
# 167  PATTERN_M-03188178      0
#
#                                                 visits  num_visits  visits_num
# 0    [Fecha: 16oct2009 OBSERVACIONES: ESPECIMEN: B0...           8           8
# 1    [Fecha: 14nov2018 ANOTACIONES: Enfermedad de C...           2           2
# 2    [Fecha: 08mar2017 PROBLEMAS DE SALUD: CONSULTA...           9           9
# 3    [Fecha: 15jul2013 ANOTACIONES: CONSULTA 15.7.1...          22          22
# 4    [Fecha: 12sep2019 ANOTACIONES: Enfermedad de C...         105          40
# ..                                                 ...         ...         ...
# 163  [Fecha: 02sep2015 OBSERVACIONES: Problema Actu...          25          25
# 164  [Fecha: 17may2012 OBSERVACIONES: ESPECIMEN: C1...          18          18
# 165  [Fecha: 25may2021 PROBLEMAS DE SALUD: Antecede...          22          22
# 166  [Fecha: 21may2017 OBSERVACIONES: Motivo de Ing...          21          21
# 167  [Fecha: 22nov2014 OBSERVACIONES: Hematies: 4.8...          25          25
#
# [168 rows x 5 columns]
